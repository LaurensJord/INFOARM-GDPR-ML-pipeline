# %% [markdown]
# ## Install the required libraries

# %%
# %pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000025838148640>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/cudatoolkit/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000025838132B50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/cudatoolkit/
# ...

# %%
import torch
import os
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
import sys
sys.path.append("./Resources")
import utils as ut

# %%
"""Load the training dataset"""
df = pd.read_csv("./Input/train_set.csv")

# %% [markdown]
# ## Load dataset

# %%
train, test = ut.load_dataset(df)
# Out:
# Train dataset size: 11374, Validation dataset size: 1863
# Total labels in train dataset: 20
# Total labels in validation dataset 17

# %% [markdown]
# ## Create directories for Models and Results

# %%
parent_directory = "./"
ut.create_directory('baseline', parent_directory)
ut.create_directory('ML', parent_directory + 'baseline')
ut.create_directory('DL', parent_directory + 'baseline')
ut.create_directory('FSL', parent_directory + 'baseline')
# Out:
# [WinError 183] Cannot create a file when that file already exists: './baseline'
# [WinError 183] Cannot create a file when that file already exists: './baseline\\ML'
# [WinError 183] Cannot create a file when that file already exists: './baseline\\DL'
# [WinError 183] Cannot create a file when that file already exists: './baseline\\FSL'

# %%
parent_directory = "./baseline/ML"
ut.create_directory('models', parent_directory)
ut.create_directory('results', parent_directory)
# Out:
# [WinError 183] Cannot create a file when that file already exists: './baseline/ML\\models'
# [WinError 183] Cannot create a file when that file already exists: './baseline/ML\\results'

# %% [markdown]
# ## Create sub directories for saving binary and multi-class Machine learning models

# %%
parent_directory = "./baseline/ML/models"
ut.create_directory('binary', parent_directory)
ut.create_directory('multiclass', parent_directory)
# Out:
# [WinError 183] Cannot create a file when that file already exists: './baseline/ML/models\\binary'
# [WinError 183] Cannot create a file when that file already exists: './baseline/ML/models\\multiclass'

# %% [markdown]
# ## Create sub directories for saving results of the binary and multi-class models

# %%
parent_directory = "./baseline/ML/results"
ut.create_directory('binary', parent_directory)
ut.create_directory('multiclass', parent_directory)
# Out:
# [WinError 183] Cannot create a file when that file already exists: './baseline/ML/results\\binary'
# [WinError 183] Cannot create a file when that file already exists: './baseline/ML/results\\multiclass'

# %% [markdown]
# ## Train all ML binary models on the training set

# %%
model_path = "./baseline/ML/models/binary/"
results_path = "./baseline/ML/results/binary/"

# %%
# ut.start_experiments_binary_ML(df, 'exp_1', results_path, model_path)

# %% [markdown]
# ## Train all ML multi-class models on the training set

# %%
model_path = "./baseline/ML/models/multiclass/"
results_path = "./baseline/ML/results/multiclass/"

# %%
# ut.start_experiments_MCC_ML(df, results_path, "exp_1", model_path)

# %% [markdown]
# ## Create sub directories for saving binary and multi-class Deep learning models

# %%
parent_directory = "./baseline/DL"
ut.create_directory('models', parent_directory)
ut.create_directory('results', parent_directory)
# Out:
# [WinError 183] Cannot create a file when that file already exists: './baseline/DL\\models'
# [WinError 183] Cannot create a file when that file already exists: './baseline/DL\\results'

# %%
parent_directory = "./baseline/DL/models"
ut.create_directory('binary', parent_directory)
ut.create_directory('multiclass', parent_directory)
# Out:
# [WinError 183] Cannot create a file when that file already exists: './baseline/DL/models\\binary'
# [WinError 183] Cannot create a file when that file already exists: './baseline/DL/models\\multiclass'

# %%
parent_directory = "./baseline/DL/results"
ut.create_directory('binary', parent_directory)
ut.create_directory('multiclass', parent_directory)
# Out:
# [WinError 183] Cannot create a file when that file already exists: './baseline/DL/results\\binary'
# [WinError 183] Cannot create a file when that file already exists: './baseline/DL/results\\multiclass'

# %% [markdown]
# ## Train all deep learning binary models on the training set

# %%
model_path = "./baseline/DL/models/binary/"
results_path = "./baseline/DL/results/binary/"

## To train MLP assign model_name NN and to train BiLSTM assign model_name BiLSTM
model_name = 'BiLSTM'

# %%
# ut.start_experiments_binary_DL(df, model_name, 'exp_1', results_path, model_path)

# %% [markdown]
# ## Train deep learning multi-class classification models on the training set

# %%
model_path = "./baseline/DL/models/multiclass/"
results_path = "./baseline/DL/results/multiclass/"

## To train MLP assign model_name NN and to train BiLSTM assign model_name BiLSTM
model_name = 'BiLSTM'

# %%
# ut.start_experiments_MCC_DL(df, model_name, results_path, 'exp_1', model_path)

# %% [markdown]
# ## Create sub directories for saving binary and multi-class few-shot learning models

# %%
parent_directory = "./baseline/FSL"
ut.create_directory('models', parent_directory)
ut.create_directory('results', parent_directory)
# Out:
# [WinError 183] Cannot create a file when that file already exists: './baseline/FSL\\models'
# [WinError 183] Cannot create a file when that file already exists: './baseline/FSL\\results'

# %%
parent_directory = "./baseline/FSL/models"
ut.create_directory('binary', parent_directory)
ut.create_directory('multiclass', parent_directory)
# Out:
# [WinError 183] Cannot create a file when that file already exists: './baseline/FSL/models\\binary'
# [WinError 183] Cannot create a file when that file already exists: './baseline/FSL/models\\multiclass'

# %%
parent_directory = "./baseline/FSL/results"
ut.create_directory('binary', parent_directory)
ut.create_directory('multiclass', parent_directory)
# Out:
# [WinError 183] Cannot create a file when that file already exists: './baseline/FSL/results\\binary'
# [WinError 183] Cannot create a file when that file already exists: './baseline/FSL/results\\multiclass'

# %% [markdown]
# ## Train all few-shot learning binary models on 30% of the training set

# %%
model_path = "./baseline/FSL/models/binary/"
results_path = "./baseline/FSL/results/binary/"
## Training dataset size in percentage
size = 0.3

# %%
# ut.few_shot_learning_binary_model(df, size, results_path, 'exp_1', model_path)

# %% [markdown]
# ## Train few-show learning multi-class classification models on 30% of the training set

# %%
model_path = "./baseline/FSL/models/multiclass/"
results_path = "./baseline/FSL/results/multiclass/"
## Training dataset size in percentage
size = 0.3

# %%
# ut.few_shot_learning_MCC_model(train, size, results_path, 'exp_1', model_path)
